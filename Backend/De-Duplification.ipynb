# %% [markdown]
# # Zip File Extration

# %%
import tarfile
import os

tar_files_dir = 'folder-1'

parent_extracted_dir = 'folder-1'

if not os.path.exists(parent_extracted_dir):
    os.makedirs(parent_extracted_dir)

for filename in os.listdir(tar_files_dir):
    file_path = os.path.join(tar_files_dir, filename)

    if os.path.isfile(file_path) and tarfile.is_tarfile(file_path):
        tar_filename = os.path.splitext(filename)[0] 
        extracted_dir = os.path.join(parent_extracted_dir, tar_filename)

        os.makedirs(extracted_dir, exist_ok=True)

        try:
            with tarfile.open(file_path, 'r:gz') as tar: 
                tar.extractall(path=extracted_dir)

            print(f'Tar file "{file_path}" has been extracted to "{extracted_dir}"')

            os.remove(file_path)

        except tarfile.ReadError as e:
            print(f'Error extracting "{file_path}": {e}. Skipping...')
        except PermissionError as e:
            print(f'Permission error for "{file_path}": {e}. Skipping...')
        except EOFError as e:
            print(f'EOFError for "{file_path}": {e}. The file might be corrupted or incomplete. Skipping...')
    else:
        print(f'Skipping non-tar file or directory: "{file_path}"')

# %%
import tarfile
import os

tar_files_dir = 'folder-2'

parent_extracted_dir = 'folder-2'

if not os.path.exists(parent_extracted_dir):
    os.makedirs(parent_extracted_dir)

for filename in os.listdir(tar_files_dir):
    file_path = os.path.join(tar_files_dir, filename)

    if os.path.isfile(file_path) and tarfile.is_tarfile(file_path):
        tar_filename = os.path.splitext(filename)[0] 
        extracted_dir = os.path.join(parent_extracted_dir, tar_filename)

        os.makedirs(extracted_dir, exist_ok=True)

        try:
            with tarfile.open(file_path, 'r:gz') as tar: 
                tar.extractall(path=extracted_dir)

            print(f'Tar file "{file_path}" has been extracted to "{extracted_dir}"')

            os.remove(file_path)

        except tarfile.ReadError as e:
            print(f'Error extracting "{file_path}": {e}. Skipping...')
        except PermissionError as e:
            print(f'Permission error for "{file_path}": {e}. Skipping...')
        except EOFError as e:
            print(f'EOFError for "{file_path}": {e}. The file might be corrupted or incomplete. Skipping...')
    else:
        print(f'Skipping non-tar file or directory: "{file_path}"')

# %% [markdown]
# # Classification

# %%
import os
txt_file1 = []
for root, dirs, files in os.walk("folder-1"):
    for file in files:
        if file.endswith(".txt"):
            file_path = os.path.join(root, file)
            txt_file1.append(file_path)
print(txt_file1)

# %%
import os
txt_file2 = []
for root, dirs, files in os.walk("folder-2"):
    for file in files:
        if file.endswith(".txt"):
            file_path = os.path.join(root, file)
            txt_file2.append(file_path)
print(txt_file2)

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

total_null_count = 0

for txt in txt_file1:
    try:
        df = pd.read_fwf(txt)
        df = df.dropna()
        total_null_count += df.isnull().sum().sum()
    except (pd.errors.EmptyDataError, FileNotFoundError) as e:
        print(f"Skipping file {txt} due to error: {e}")

print(total_null_count)

# %%
import pandas as pd

total_null_count = 0

for txt in txt_file2:
    try:
        df = pd.read_fwf(txt)
        df = df.dropna()
        total_null_count += df.isnull().sum().sum()
    except (pd.errors.EmptyDataError, FileNotFoundError) as e:
        print(f"Skipping file {txt} due to error: {e}")

print(total_null_count)

# %% [markdown]
# # TF-IDF and Cosine Similarity

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Function to tokenize text and perform lemmatization
def tokenize_text_lemmatization(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token.lower() for token in tokens if token.isalpha() and token.lower() not in stop_words]

    # Check if all tokens are stop words
    if not tokens:
        # If all tokens are stop words, add a placeholder token to avoid empty vocabulary
        tokens = ['placeholder']

    # Perform lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    return tokens

# Function to calculate TF-IDF for a list of file paths
def calculate_tfidf_for_file_list(file_paths):
    tfidf_matrices = []

    for file_path in file_paths:
        # Tokenize each file
        tokenized_texts_lemmatization = tokenize_text_lemmatization(file_path)

        # Convert tokenized texts to string for TfidfVectorizer
        tokenized_texts_str = ' '.join(tokenized_texts_lemmatization)

        # Create TfidfVectorizer
        vectorizer = TfidfVectorizer()

        # Fit and transform the tokenized texts
        tfidf_matrix = vectorizer.fit_transform([tokenized_texts_str])

        # Get feature names (terms)
        feature_names = vectorizer.get_feature_names_out()

        # Convert the TF-IDF matrix to a dense array for easier manipulation
        dense_tfidf_matrix = tfidf_matrix.todense()

        # Create a DataFrame for better visualization (optional)
        import pandas as pd
        df_tfidf = pd.DataFrame(dense_tfidf_matrix, columns=feature_names)

        tfidf_matrices.append(df_tfidf)

    return tfidf_matrices

# Calculate TF-IDF for each list of file paths
tfidf_folder1 = calculate_tfidf_for_file_list(txt_file1)
tfidf_folder2 = calculate_tfidf_for_file_list(txt_file2)


# calculate the cosine similarity between the matrices
for tfidf_matrix1 in tfidf_folder1:
    for tfidf_matrix2 in tfidf_folder2:
        similarity_matrix = cosine_similarity(tfidf_matrix1, tfidf_matrix2)
        print(f"Cosine Similarity Matrix between files in folder1 and folder2:")
        print(similarity_matrix)

# %%
# from pyspark.sql import SparkSession
# from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, IDF
# from pyspark.ml.linalg import DenseVector
# from pyspark.ml import Pipeline
# from pyspark.sql.functions import udf
# from pyspark.sql.types import DoubleType
# from pyspark import SparkContext

# # Initialize Spark session
# spark = SparkSession.builder.appName("TFIDFComparison").getOrCreate()
# sc = SparkContext.getOrCreate()

# # Function to read text file
# def read_text_file(file_path):
#     with open(file_path, 'r', encoding='utf-8') as file:
#         text = file.read()
#     return text

# # UDF to perform lemmatization (you can replace it with your own lemmatization logic)
# @udf
# def lemmatize_udf(text):
#     # Your lemmatization logic here
#     return text

# # UDF to convert sparse vector to dense vector
# @udf(DenseVector)
# def sparse_to_dense(vector):
#     return DenseVector(vector.toArray())

# # Function to calculate cosine similarity
# def calculate_cosine_similarity(v1, v2):
#     dot_product = v1.dot(v2)
#     magnitude_v1 = v1.norm(2)
#     magnitude_v2 = v2.norm(2)
#     similarity = dot_product / (magnitude_v1 * magnitude_v2)
#     return similarity

# # Create DataFrame from text files
# df_folder1 = spark.createDataFrame([(file_path, read_text_file(file_path)) for file_path in txt_file1], ["path", "text"])
# df_folder2 = spark.createDataFrame([(file_path, read_text_file(file_path)) for file_path in txt_file2], ["path", "text"])

# # Tokenize, remove stopwords, and calculate TF
# tokenizer = Tokenizer(inputCol="text", outputCol="words")
# remover = StopWordsRemover(inputCol="words", outputCol="filtered")
# vectorizer = CountVectorizer(inputCol="filtered", outputCol="tf_features")

# # Create a Pipeline
# pipeline = Pipeline(stages=[tokenizer, remover, vectorizer])
# model = pipeline.fit(df_folder1.union(df_folder2))

# # Transform the data
# df_folder1 = model.transform(df_folder1)
# df_folder2 = model.transform(df_folder2)

# # Calculate IDF
# idf = IDF(inputCol="tf_features", outputCol="idf_features")
# idf_model = idf.fit(df_folder1.union(df_folder2))
# df_folder1 = idf_model.transform(df_folder1)
# df_folder2 = idf_model.transform(df_folder2)

# # Convert sparse vectors to dense vectors
# df_folder1 = df_folder1.withColumn("dense_features", sparse_to_dense("idf_features"))
# df_folder2 = df_folder2.withColumn("dense_features", sparse_to_dense("idf_features"))

# # Calculate cosine similarity
# result = df_folder1.crossJoin(df_folder2)\
#     .withColumn("cosine_similarity", calculate_cosine_similarity("dense_features", "dense_features"))\
#     .select("path", "path", "cosine_similarity")

# # Show the result
# result.show(truncate=False)
# #

# %%
import os
import hashlib

def calculate_sha256(file_path, block_size=4096):
    sha256_hash = hashlib.sha256()
    
    with open(file_path, "rb") as file:
        for byte_block in iter(lambda: file.read(block_size), b""):
            sha256_hash.update(byte_block)

    return sha256_hash.hexdigest()

def generate_file_hashes(folder_path):
    file_hashes = {}

    for root, dirs, files in os.walk(folder_path):
        for file_name in files:
            file_path = os.path.join(root, file_name)

            # Calculate SHA-256 hash only if file size and modification time match
            file_stats = os.stat(file_path)
            key = (file_stats.st_size, file_stats.st_mtime)

            if key not in file_hashes:
                file_hashes[key] = calculate_sha256(file_path)

    return file_hashes

# Example usage:
source_folder = "folder-1"
destination_folder = "folder-2"

# Generate hash values for files in each folder
source_hashes = generate_file_hashes(source_folder)
destination_hashes = generate_file_hashes(destination_folder)

# Identify duplicate files
duplicate_files = {key for key in source_hashes if key in destination_hashes}

# Display duplicate files
print("Duplicate Files:")
for key in duplicate_files:
    print(f"- {key}")

# %%
import os
import xxhash

def calculate_hash(file_path, chunk_size=4096):
    hasher = xxhash.xxh64()
    with open(file_path, 'rb') as file:
        while True:
            data = file.read(chunk_size)
            if not data:
                break
            hasher.update(data)
    return hasher.hexdigest()

def find_duplicates(folder1, folder2):
    hash_table = {}

    # Process files in the first folder
    for root, dirs, files in os.walk(folder1):
        for file in files:
            file_path = os.path.join(root, file)
            file_hash = calculate_hash(file_path)
            hash_table[file_hash] = file_path

    # Check files in the second folder for duplicates
    duplicate_files = []
    for root, dirs, files in os.walk(folder2):
        for file in files:
            file_path = os.path.join(root, file)
            file_hash = calculate_hash(file_path)
            if file_hash in hash_table:
                duplicate_files.append((file_path, hash_table[file_hash]))

    return duplicate_files

if __name__ == "__main__":
    folder1 = "folder-1"
    folder2 = "folder-2"

    duplicates = find_duplicates(folder1, folder2)

    if duplicates:
        print("Duplicate files found:")
        for file1, file2 in duplicates:
            print(f"{file1} and {file2}")
    else:
        print("No duplicate files found.")
# Out:
# Duplicate files found:
# folder-2\08456059.pdf and folder-1\08456059.pdf
# folder-2\20180006549.pdf and folder-1\20180006549.pdf
# folder-2\235434231_RAW_PAN.pix and folder-1\235434231_RAW_PAN.pix
# folder-2\235434251_RAW_PAN_LOG.txt and folder-1\235434251_RAW_PAN_LOG.txt
# folder-2\3.205-CVE_to_be_installed.txt and folder-1\3.205-CVE_to_be_installed.txt
# folder-2\3.207-CVE_to_be_installed.txt and folder-1\3.207-CVE_to_be_installed.txt
# folder-2\3.208-CVE_to_be_installed.txt and folder-1\3.207-CVE_to_be_installed.txt
# folder-2\anaconda-ks.cfg and folder-1\anaconda-ks.cfg
# folder-2\authorized_keys-4-8-17 and folder-1\authorized_keys-4-8-17
# folder-2\BAND_RPC.txt and folder-1\BAND_RPC.txt
# folder-2\buttons.print.min.js and folder-1\buttons.print.min.js
# folder-2\catalina.2023-07-14.log and folder-1\catalina.2023-07-14.log
# folder-2\catalina.2023-07-16.log and folder-1\catalina.2023-07-16.log
# folder-2\catalina.2023-07-23.log and folder-1\catalina.2023-07-23.log
# folder-2\catalina.2023-08-26.log and folder-1\catalina.2023-08-26.log
# folder-2\covid_excel_20-38.xlsx and folder-1\covid_excel_20-38.xlsx
# folder-2\ddn-restapi-core-gs-4.2.1-3.3d53e4_dirty.noarch.rpm and folder-1\ddn-restapi-core-gs-4.2.1-3.3d53e4_dirty.noarch.rpm
# folder-2\EaseUS Partition Master 9.2.2 Technician Edition (FULL + Patch).zip and folder-1\EaseUS Partition Master 9.2.2 Technician Edition (FULL + Patch).zip
# folder-2\fio-3.1-1.el6.x86_64.rpm and folder-1\fio-3.1-1.el6.x86_64.rpm
# folder-2\gpfs.gss.pmsensors-4.2.3-5.el7.x86_64.rpm and folder-1\gpfs.gss.pmsensors-4.2.3-5.el7.x86_64.rpm
# folder-2\gwm66c08.jpg and folder-1\gwm66c08.jpg
# folder-2\import CSV.txt and folder-1\import CSV.txt
# folder-2\KKD geo tagging (1).xlsx and folder-1\KKD geo tagging (1).xlsx
# folder-2\KKD geo tagging (2).xlsx and folder-1\KKD geo tagging (1).xlsx
# folder-2\KKD geo tagging (3).xlsx and folder-1\KKD geo tagging (1).xlsx
# folder-2\KKD geo tagging.xlsx and folder-1\KKD geo tagging (1).xlsx
# folder-2\LS____.pdf and folder-1\LS____.pdf
# folder-2\mmhealth.sh and folder-1\mmhealth.sh
# folder-2\mounted and folder-1\mounted
# folder-2\NewGCPs.bk and folder-1\NewGCPs.bk
# folder-2\NewGCPs.prj and folder-1\NewGCPs.bk
# folder-2\SR170158_ddn_showall_20210902-13_20_38.tar.gz and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar.gz
# folder-2\syslog and folder-1\syslog
# folder-2\table.sql and folder-1\table.sql
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmauth_show_all.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmauth_show_all.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmfsadm_dump_verbs.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmfsadm_dump_verbs.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmfsadm_test_verbs_config.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmfsadm_test_verbs_config.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmfsadm_test_verbs_status.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmfsadm_test_verbs_status.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmfsadm_verbs_conn.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmfsadm_verbs_conn.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmfs_bin_mmnfsup.mmnfsup and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\mmfs_bin_mmnfsup.mmnfsup
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmlsconfig.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmlsconfig.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmlsdisk_m.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmlsdisk_m.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\mmnfsmonitor_status.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\mmnfsmonitor_status.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\rpm_qi_gpfs_base.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\rpm_qi_gpfs_base.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170904.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170904.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170905.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170905.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170906.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170906.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170907.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170907.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170908.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170908.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170909.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170909.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170910.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170910.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170911.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170911.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170912.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170912.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170913.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170913.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170914.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170914.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170915.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170915.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170916.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170916.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170917.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170917.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170918.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170918.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170919.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170919.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170920.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170920.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170921.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170921.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170922.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170922.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170923.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170923.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170924.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170924.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170925.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170925.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170926.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170926.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170927.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170927.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170928.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170928.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170929.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170929.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20170930.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20170930.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20171001.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20171001.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20171002.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20171002.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.mmsysmonitor.log-20171003.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.mmsysmonitor.log-20171003.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.adm.ras.rasdb_2020-09-25_10-30-59.026458.tar.gz and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.adm.ras.rasdb_2020-09-25_10-30-59.026458.tar.gz
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.ccr.disks and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.ccr.noauth and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.noauth
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.ccr.nodes and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.8.26db5368.020dc22c19
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.ccr.nsdmap and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver4-bond0\gpfs\var.mmfs.ccr.ccr.nsdmap
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.authccr.20.1.c114e3bb.0135c1b02c and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.authccr.20.1.c114e3bb.0135c1b02c
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.ccr.disks.2.24.140134dd.0207c0680a and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.ccr.disks.2.24.140134dd.0207c0680a
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.ccr.disks.2.25.ffffffff.0207c0680c and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.7.3fc2d609.020dc22c17 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.7.3fc2d609.020dc22c17
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.8.26db5368.020dc22c19 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.8.26db5368.020dc22c19
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.cesiplist.12.67.f9bb92ed.0136c1b4d9 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.cesiplist.12.67.f9bb92ed.0136c1b4d9
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.clusterEvents.8.125759.8594ecb1.020ac1b66c.tmp.4391.1174386432 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.mmfs.ccr.committed.clusterEvents.8.125759.8594ecb1.020ac1b66c.tmp.4391.1174386432
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.clusterEvents.8.154446.fffb4f51.020cc22bde and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.clusterEvents.8.154446.fffb4f51.020cc22bde
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.clusterEvents.8.154447.fd9c5cf8.0300c22be0 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.clusterEvents.8.154447.fd9c5cf8.0300c22be0
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.collectors.11.82.c3ed6ebf.013cc22ca5 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.collectors.11.75.c3ed6ebf.0405c22c09
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.collectors.11.83.c3ed6ebf.013cc22ca6 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.collectors.11.75.c3ed6ebf.0405c22c09
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.genKeyData.4.1.f806a4d.010003 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyData.4.1.f806a4d.010003
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.genKeyDataNew.5.1.f806a4d.010004 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyData.4.1.f806a4d.010003
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.genKeyDataNew.5.2.1fffa38f.01268a16 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyDataNew.5.2.1fffa38f.01268a16
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.exports.conf.17.7.d6140467.0135c1b051 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.exports.conf.17.7.d6140467.0135c1b051
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.log.conf.16.3.533d299a.0135c1b010 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.log.conf.16.3.533d299a.0135c1b010
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.main.conf.14.3.9612acae.0135c1b00e and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.main.conf.14.3.9612acae.0135c1b00e
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.nfsd.conf.15.3.20ce023b.0135c1b00f and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.nfsd.conf.15.3.20ce023b.0135c1b00f
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.statdargs.conf.18.3.abaf58a9.0135c1b012 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.statdargs.conf.18.3.abaf58a9.0135c1b012
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.idmapd.conf.19.3.b905a8d2.0135c1b013 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.idmapd.conf.19.3.b905a8d2.0135c1b013
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.mmLockFileDB.3.1.ffffffff.010002 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.1.cee097c7.0131c0663c and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.1.cee097c7.0131c0663c
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.2.52721450.0138c1d176 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.2.52721450.0138c1d176
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.smb.ctdb.nodes.13.5.ca364a0d.0136c1b4e2 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.smb.ctdb.nodes.13.5.ca364a0d.0136c1b4e2
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.zmrules.json.10.4.2dde4dd9.0136c1b57f and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.zmrules.json.10.4.2dde4dd9.0136c1b57f
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed.zmrules.json.10.5.165c3a2.0136c1b581 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.zmrules.json.10.5.165c3a2.0136c1b581
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.4.8a7a7086.010110 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.etc.mmfsdown and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsdown
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.etc.mmfsup and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsup
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.etc.nsddevices and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.nsddevices
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.cesAddressPoolFile and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.minFreeSpace984 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfs.cfg and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.mmfs.gen.mmfs.cfg
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfs.cfg.ls and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.mmfs.gen.mmfs.cfg.ls
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfs.cfg.raw and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.mmfs.gen.mmfs.cfg.raw
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfs.cfg.show and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.mmfs.gen.mmfs.cfg.show
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfsCommittedKeyLevel1 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfsEnvLevel743 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfsNewKeyLevel2 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfsNodeData and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\gpfs\var.mmfs.gen.mmfsNodeData
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.mmfsVfsNumber239 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsaixnodes.dae and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsaixnodes.ipa and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsaixnodes.num and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsaixnodes.rel and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscesnodes.dae and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscesnodes.ipa and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscesnodes.num and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscesnodes.rel and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscnfsnodes.dae and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscnfsnodes.ipa and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscnfsnodes.num and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfscnfsnodes.rel and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsdisabledcnfsnodes.dae and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsdisabledcnfsnodes.ipa and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsdisabledcnfsnodes.num and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsdisabledcnfsnodes.rel and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsenabledcnfsnodes.dae and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsenabledcnfsnodes.ipa and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsenabledcnfsnodes.num and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsenabledcnfsnodes.rel and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsmanagernodes.dae and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsmanagernodes.ipa and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.ipa
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsmanagernodes.num and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.num
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsmanagernodes.rel and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsnsdnodes.dae and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsnsdnodes.ipa and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.ipa
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsnsdnodes.num and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.num
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsnsdnodes.rel and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.dae and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.ipa and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.ipa
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.num and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.num
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.rel and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsquorumnodes.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.dae and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.ipa and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.ipa
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.num and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.num
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.mmfsserverlicense.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.dae and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.ipa and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.ipa
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.num and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.num
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.rel and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.nodeFiles.useraddm_clients.rel
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.nsdmap and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver4-bond0\gpfs\var.mmfs.gen.nsdmap
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.perfmon.cfg and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.perfmon.cfg
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.rerunmmfsFile and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gpfs\var.mmfs.gen.shellCallbackFile and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.shellCallbackFile
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\gs\sfa_conf.sfa.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\storage\etc_ddn_sfa_conf.sfa.conf
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\infiniband\ibdiag.ibdiag.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\infiniband\ibdiag.ibdiag.conf
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\infiniband\ibstat.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\infiniband\ibstat.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\infiniband\ibv_devices.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\infiniband\ibv_devices.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\infiniband\ibv_devinfo.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\infiniband\ibv_devinfo.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\infiniband\infiniband_diags_error_thresholds.error_thresholds and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\infiniband\infiniband_diags_error_thresholds.error_thresholds
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\mofed\etc.infiniband.connectx.conf and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-bond0 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\etc.sysconfig.network-scripts.ifcfg-bond0
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-em1 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\etc.sysconfig.network-scripts.ifcfg-em1
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-em2 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\etc.sysconfig.network-scripts.ifcfg-em2
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-em3 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\etc.sysconfig.network-scripts.ifcfg-em3
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-em4 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\etc.sysconfig.network-scripts.ifcfg-em4
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-lo and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\network\etc.sysconfig.network-scripts.ifcfg-lo
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-p4p1 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\network\etc.sysconfig.network-scripts.ifcfg-p4p1
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\etc.sysconfig.network-scripts.ifcfg-p4p2 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\network\etc.sysconfig.network-scripts.ifcfg-p4p2
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\ethtool.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\ethtool.txt
# folder-2\SR153362_ddn_showall_20201029-15_03_32.tar\SR153362_ddn_showall_20201029-15_03_32\172.26.5.151\network\ip_a.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver1-bond0\network\ip_a.txt
# ...
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.statdargs.conf.18.3.abaf58a9.0135c1b012 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.gpfs.ganesha.statdargs.conf.18.3.abaf58a9.0135c1b012
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.11.85498412.01068014.tmp.51472.2929534720 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.11.85498412.01068014.tmp.51472.3346118400 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.11.fc833613.01078018.tmp.12668.3030144768 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.13.f0d42865.0109802c.tmp.13230.1374783232 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.1.cee097c7.0131c0663c and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.1.cee097c7.0131c0663c
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.zmrules.json.10.4.2dde4dd9.0136c1b57f and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver7-bond0\gpfs\var.mmfs.ccr.committed.zmrules.json.10.4.2dde4dd9.0136c1b57f
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.4.8a7a7086.010110 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.etc.mmfsdown and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsdown
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.etc.mmfsup and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsup
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.etc.nsddevices and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.nsddevices
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.gen.mmfsEnvLevel811 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver7-bond0\gpfs\var.mmfs.gen.perfmon.cfg and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.gen.perfmon.cfg
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.disks and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.noauth and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.noauth
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.nodes and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.8.26db5368.020dc22c19
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.paxos.1 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.paxos.1
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.paxos.2 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.ccr.paxos.2
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.disks.2.25.ffffffff.0207c0680c and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.7.3fc2d609.020dc22c17 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.7.3fc2d609.020dc22c17
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.8.26db5368.020dc22c19 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.ccr.nodes.1.8.26db5368.020dc22c19
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.clusterEvents.8.154447.fd9c5cf8.0300c22be0 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.clusterEvents.8.154447.fd9c5cf8.0300c22be0
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.collectors.11.74.c3ed6ebf.0405c22c08 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.collectors.11.75.c3ed6ebf.0405c22c09
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.collectors.11.75.c3ed6ebf.0405c22c09 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.collectors.11.75.c3ed6ebf.0405c22c09
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyData.4.1.f806a4d.010003 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyData.4.1.f806a4d.010003
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyDataNew.5.2.1fffa38f.01268a16 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.genKeyDataNew.5.2.1fffa38f.01268a16
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmLockFileDB.3.1.ffffffff.010002 and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.709.bed8ee05.020dc22c14 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.709.bed8ee05.020dc22c14
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.710.ed2e3e7b.020dc22c1a and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsdrfs.6.710.ed2e3e7b.020dc22c1a
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.2.52721450.0138c1d176 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.mmsysmon.json.9.2.52721450.0138c1d176
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.zmrules.json.10.5.165c3a2.0136c1b581 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed.zmrules.json.10.5.165c3a2.0136c1b581
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111 and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.ccr.committed._callhomeconfig.7.5.8a7a7086.010111
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsdown and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsdown
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsup and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.mmfsup
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\ioserver8-bond0\gpfs\var.mmfs.etc.nsddevices and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\ioserver8-bond0\gpfs\var.mmfs.etc.nsddevices
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\nodes_available.txt and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\nodes_available.txt
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\nodes_duplicated.txt and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\nodes_unavailable.txt and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\nodes_unresolved.txt and folder-1\SR170158_ddn_showall_20210902-13_20_38.tar\SR170158_ddn_showall_20210902-13_20_38\ioserver1-bond0\rest\var.log.restapi.nginx.access.log
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\gpfs.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\gpfs.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\gs.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\gs.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\gs42.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\gs42.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\infiniband.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\infiniband.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\mofed.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\mofed.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\nasctl.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\nasctl.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\network.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\network.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\nfs.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\nfs.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\opa.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\opa.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\rest.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\rest.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\storage.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\storage.conf
# folder-2\SR201434_ddn_showall_20230424-16_44_50.tar\SR201434_ddn_showall_20230424-16_44_50\showall-meta\showall.d\system.conf and folder-1\SR159360_ddn_showall_20210222-13_54_51.tar\SR159360_ddn_showall_20210222-13_54_51\showall-meta\showall.d\system.conf

# %%
# Out:
#   Cell In[8], line 1
#     --NotebookApp.iopub_data_rate_limit=100000000
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
